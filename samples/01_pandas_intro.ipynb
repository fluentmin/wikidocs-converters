# %% [markdown]
# # Chapter 1. Pandas 첫걸음
#
# 이 노트북은 `/wikidocs:convert` 의 **노트북(.ipynb) 파이프라인** 샘플입니다.
# 코드와 함께 **실제 실행 결과(로그·표·그림)** 까지 그대로 싣는 것이 핵심입니다.

# %% [markdown]
# ## 데이터 불러오기
# 간단한 DataFrame 을 만듭니다.

# %%
import pandas as pd
df = pd.DataFrame({'도시': ['서울','부산','대구'], '인구(만)': [966, 334, 238]})
print(df.shape)
# Out:
# (3, 2)

# %% [markdown]
# ## 기본 통계
# 요약 통계를 봅니다.

# %%
df
# Out:
#     도시  인구(만)
# 0  서울    966
# 1  부산    334
# 2  대구    238

# %% [markdown]
# ## 시각화
# 막대그래프로 그립니다.

# %%
import matplotlib.pyplot as plt
df.plot.bar(x='도시', y='인구(만)')
plt.show()
